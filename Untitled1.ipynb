# %% [markdown]
# ### **1.Preprocessing**

# %%
#importing
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


#nltk.download('punkt')
#nltk.download('stopwords')
#nltk.download('wordnet')

#file loading
file_path = '/content/nfr.txt'
with open(file_path, "r") as file:
    content = file.read()

# Step 1: Data Cleaning
content_clean = re.sub(r'\n+', ' ', content)
content_clean = re.sub(r'\s+', ' ', content)
content_clean = re.sub(r'[^a-zA-Z\s]', '', content_clean)
content_clean = content_clean.lower()

# Step 2: Sentence Tokenization
sentences = sent_tokenize(content_clean)

# Step 3: Word Tokenization
tokens = [word_tokenize(sentence) for sentence in sentences]

# Step 4: Stop Words Removal
stop_words = set(stopwords.words('english'))
filtered_tokens = [[word for word in sentence if word not in stop_words] for sentence in tokens]

# Step 5: Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [[lemmatizer.lemmatize(word) for word in sentence] for sentence in filtered_tokens]

# Step 6: Rejoin Tokens for Categorization
preprocessed_text = [' '.join(sentence) for sentence in lemmatized_tokens]

# %% [markdown]
# ### **2.Categorization**
#
# ##### So that we can easily monitor the different categories of requirements easily :)

# %%
from collections import defaultdict
requirements = defaultdict(list)


for line in content.splitlines():
    if line.strip():
        parts = line.split(":", 1)
        if len(parts) == 2:
            prefix = parts[0].strip()
            content = parts[1].strip()

            # Add the content to the appropriate category in the dictionary
            requirements[prefix].append(content)



# number of requirements in each category
for key, reqs in requirements.items():
    print(f"{key}: {len(reqs)} requirements")
# Out:
# PE: 54 requirements
# LF: 38 requirements
# US: 67 requirements
# A: 21 requirements
# SE: 66 requirements
# F: 255 requirements
# L: 13 requirements
# O: 62 requirements
# SC: 21 requirements
# FT: 10 requirements
# MN: 17 requirements
# PO: 1 requirements

# %%
category_key = "PO"  # Replace with the desired category key
if category_key in requirements:
    category_requirements = requirements[category_key]

    print(f"Requirements for category '{category_key}':")
    for req in category_requirements:
        print(f"- {req}")
# Out:
# Requirements for category 'PO':
# - The product is expected to run on Windows CE and Palm operating systems.

# %%
#pip install spacy

# %% [markdown]
# ### **3.Custom NER**

# %%
import spacy

# %%
#!python -m spacy download en_core_web_sm

# %%
import json
from spacy.matcher import PhraseMatcher
nlp = spacy.load("en_core_web_sm")

# Define custom NER function
def custom_ner(doc, custom_entities):
    actors = []
    actions = []
    conditions = []

    # Creating phrase matchers for multi-token entities
    matcher = PhraseMatcher(nlp.vocab)

    # Ading custom entities to matchers
    actor_patterns = [nlp.make_doc(actor.lower()) for actor in custom_entities['Actor']]
    action_patterns = [nlp.make_doc(action.lower()) for action in custom_entities['Action']]
    condition_patterns = [nlp.make_doc(condition.lower()) for condition in custom_entities['Condition']]

    matcher.add("ACTOR", None, *actor_patterns)
    matcher.add("ACTION", None, *action_patterns)
    matcher.add("CONDITION", None, *condition_patterns)

    # Finding matches for actors, actions, and conditions
    matches = matcher(doc)

    for match_id, start, end in matches:
        span = doc[start:end].text
        label = nlp.vocab.strings[match_id]

        if label == "ACTOR":
            actors.append(span)
        elif label == "ACTION":
            actions.append(span)
        elif label == "CONDITION":
            conditions.append(span)

    return actors, actions, conditions, []

# Function to process requirements
def process_requirements(requirements, custom_entities, replace_terms=None):
    results = []
    for requirement in requirements:
        if replace_terms:
            for old_term, new_term in replace_terms.items():
                requirement = requirement.replace(old_term, new_term)

        # Tokenize and analyze the text with spaCy
        doc = nlp(requirement)

        # Extract custom entities
        actors, actions, conditions, _ = custom_ner(doc, custom_entities)

        # For now, use the entire requirement as the outcome
        outcomes = [requirement]

        results.append({
            "Requirement": requirement,
            "Actors": actors,
            "Actions": actions,
            "Conditions": conditions,
            "Outcomes": outcomes
        })
    return results

# Loading custom entities from JSON file and convert to dictionary
with open('/content/custom_entities.json', 'r') as f:
    custom_entities = json.load(f)

#loading requiremnts
requirements_po = requirements['PO']
requirements_ft = requirements['FT']
requirements_l = requirements['L']
requirements_mn = requirements['MN']
requirements_a = requirements['A']
requirements_sc = requirements['SC']
requirements_lf = requirements['LF']
requirements_pe = requirements['PE']
requirements_se = requirements['SE']
requirements_o = requirements['O']
requirements_us = requirements['US']
requirements_f = requirements['F']

# Process each set of requirements
results_po = process_requirements(requirements_po, custom_entities['PO'])
results_ft = process_requirements(requirements_ft, custom_entities['FT'], replace_terms={"shall": "should"})
results_l = process_requirements(requirements_l, custom_entities['L'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_mn = process_requirements(requirements_mn, custom_entities['MN'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_a = process_requirements(requirements_a, custom_entities['A'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_sc = process_requirements(requirements_sc, custom_entities['SC'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_lf = process_requirements(requirements_lf, custom_entities['LF'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_pe = process_requirements(requirements_pe, custom_entities['PE'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_se = process_requirements(requirements_se, custom_entities['SE'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_o = process_requirements(requirements_o, custom_entities['O'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_us = process_requirements(requirements_us, custom_entities['US'], replace_terms={"shall": "should", "will": "should", "must": "should"})
results_f = process_requirements(requirements_f, custom_entities['F'], replace_terms={"shall": "should", "will": "should", "must": "should"})

# Combine all results
output = {
    "PO": results_po,
    "FT": results_ft,
    "L": results_l,
    "MN": results_mn,
    "A": results_a,
    "SC": results_sc,
    "LF": results_lf,
    "PE": results_pe,
    "SE": results_se,
    "O": results_o,
    "US": results_us,
    "F": results_f
}

# Print or save the output
print(json.dumps(output, indent=2))
# Out:
# {
#   "PO": [
#     {
#       "Requirement": "The product is expected to run on Windows CE and Palm operating systems.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "run"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product is expected to run on Windows CE and Palm operating systems."
#       ]
#     }
#   ],
#   "FT": [
#     {
#       "Requirement": "The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "create"
#       ],
#       "Conditions": [
#         "exception log"
#       ],
#       "Outcomes": [
#         "The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution."
#       ]
#     },
#     {
#       "Requirement": "The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.",
#       "Actors": [
#         "product",
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "remain"
#       ],
#       "Conditions": [
#         "malicious data",
#         "malicious data"
#       ],
#       "Outcomes": [
#         "The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product."
#       ]
#     },
#     {
#       "Requirement": "The website should continue to operate if the streaming server goes down.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [
#         "continue",
#         "operate"
#       ],
#       "Conditions": [
#         "streaming server"
#       ],
#       "Outcomes": [
#         "The website should continue to operate if the streaming server goes down."
#       ]
#     },
#     {
#       "Requirement": "The website should continue to operate if the payment gateway goes down.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [
#         "continue",
#         "operate"
#       ],
#       "Conditions": [
#         "payment gateway"
#       ],
#       "Outcomes": [
#         "The website should continue to operate if the payment gateway goes down."
#       ]
#     },
#     {
#       "Requirement": "The product should be robust.The product should have fault avoidance based on standards adoption.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "standards adoption"
#       ],
#       "Outcomes": [
#         "The product should be robust.The product should have fault avoidance based on standards adoption."
#       ]
#     },
#     {
#       "Requirement": "The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "fault tolerance",
#         "fault tolerance",
#         "recovery technique",
#         "compensatory transaction"
#       ],
#       "Outcomes": [
#         "The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures."
#       ]
#     },
#     {
#       "Requirement": "The product should operate in offline mode whenever internet connection is unavailable.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "operate"
#       ],
#       "Conditions": [
#         "offline mode"
#       ],
#       "Outcomes": [
#         "The product should operate in offline mode whenever internet connection is unavailable."
#       ]
#     },
#     {
#       "Requirement": "The product should allow the user to view previously downloaded search results  CMA reports  and appointments.",
#       "Actors": [
#         "product",
#         "user"
#       ],
#       "Actions": [
#         "allow"
#       ],
#       "Conditions": [
#         "previously downloaded search results",
#         "appointments"
#       ],
#       "Outcomes": [
#         "The product should allow the user to view previously downloaded search results  CMA reports  and appointments."
#       ]
#     },
#     {
#       "Requirement": "The product should retain user preferences in the event of a failure.",
#       "Actors": [
#         "product",
#         "user"
#       ],
#       "Actions": [
#         "retain"
#       ],
#       "Conditions": [
#         "user preferences"
#       ],
#       "Outcomes": [
#         "The product should retain user preferences in the event of a failure."
#       ]
#     },
#     {
#       "Requirement": "100% of saved user preferences should be restored when system comes back online.",
#       "Actors": [
#         "user"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "user preferences"
#       ],
#       "Outcomes": [
#         "100% of saved user preferences should be restored when system comes back online."
#       ]
#     }
#   ],
#   "L": [
#     {
#       "Requirement": "All business rules specified in the Disputes System should be in compliance to the guidelines of Regulation E and Regulation Z.",
#       "Actors": [
#         "business rules"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "All business rules specified in the Disputes System should be in compliance to the guidelines of Regulation E and Regulation Z."
#       ]
#     },
#     {
#       "Requirement": "The Disputes application should maintain a detailed history of every action that a user takes on a dispute case.  This ensures a complete audit trail if questions arise later on with regard to a particular dispute case.",
#       "Actors": [],
#       "Actions": [
#         "maintain"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The Disputes application should maintain a detailed history of every action that a user takes on a dispute case.  This ensures a complete audit trail if questions arise later on with regard to a particular dispute case."
#       ]
#     },
#     {
#       "Requirement": "All actions that modify an existing dispute case should be recorded in the case history.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "All actions that modify an existing dispute case should be recorded in the case history."
#       ]
#     },
#     {
#       "Requirement": "The product should comply with Sarbanes-Oxley.",
#       "Actors": [],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should comply with Sarbanes-Oxley."
#       ]
#     },
#     {
#       "Requirement": "The product should comply with the estimatics laws relating to recycled parts usage.",
#       "Actors": [],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [
#         "estimatics laws"
#       ],
#       "Outcomes": [
#         "The product should comply with the estimatics laws relating to recycled parts usage."
#       ]
#     },
#     {
#       "Requirement": "The product should comply with insurance regulations regarding claims processing.",
#       "Actors": [],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [
#         "insurance regulations"
#       ],
#       "Outcomes": [
#         "The product should comply with insurance regulations regarding claims processing."
#       ]
#     },
#     {
#       "Requirement": "The System should meet all applicable accounting standards.  The final version of the System should successfully pass independent audit performed by a certified auditor.",
#       "Actors": [],
#       "Actions": [
#         "meet"
#       ],
#       "Conditions": [
#         "accounting standards"
#       ],
#       "Outcomes": [
#         "The System should meet all applicable accounting standards.  The final version of the System should successfully pass independent audit performed by a certified auditor."
#       ]
#     },
#     {
#       "Requirement": "IzognMovies should meet the licensing requirements set forth by the appropriate organizations in order to stream African movies.",
#       "Actors": [
#         "organizations"
#       ],
#       "Actions": [
#         "meet"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "IzognMovies should meet the licensing requirements set forth by the appropriate organizations in order to stream African movies."
#       ]
#     },
#     {
#       "Requirement": "The website should comply with W3C standards.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should comply with W3C standards."
#       ]
#     },
#     {
#       "Requirement": "The PHP code should comply with PEAR standards.",
#       "Actors": [],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The PHP code should comply with PEAR standards."
#       ]
#     },
#     {
#       "Requirement": "The Disputes application should conform to the legal requirements as specified by the Merchant Operating Regulations.",
#       "Actors": [],
#       "Actions": [
#         "conform"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The Disputes application should conform to the legal requirements as specified by the Merchant Operating Regulations."
#       ]
#     },
#     {
#       "Requirement": "All business rules specified in the Disputes System should be in compliance with the Merchant Operating Regulations.",
#       "Actors": [
#         "business rules"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "All business rules specified in the Disputes System should be in compliance with the Merchant Operating Regulations."
#       ]
#     },
#     {
#       "Requirement": "The Disputes application should conform to the legal requirements as specified by Regulation E and Regulation Z that govern credit card disputes processing.",
#       "Actors": [],
#       "Actions": [
#         "conform"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The Disputes application should conform to the legal requirements as specified by Regulation E and Regulation Z that govern credit card disputes processing."
#       ]
#     }
#   ],
#   "MN": [
#     {
#       "Requirement": "The product should be designed using Design Patterns and coding best practices.  90% of maintenance software developers are able to integrate new functionality into the product with 2 working days.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "integrate"
#       ],
#       "Conditions": [
#         "coding best practices"
#       ],
#       "Outcomes": [
#         "The product should be designed using Design Patterns and coding best practices.  90% of maintenance software developers are able to integrate new functionality into the product with 2 working days."
#       ]
#     },
#     {
#       "Requirement": "The product should be highly configurable for use with various database management systems for the end users.  80% of end users are able to integrate new database management systems with the product without changing the product\ufffds software code.",
#       "Actors": [
#         "product",
#         "end users",
#         "end users",
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "integrate"
#       ],
#       "Conditions": [
#         "various database management systems"
#       ],
#       "Outcomes": [
#         "The product should be highly configurable for use with various database management systems for the end users.  80% of end users are able to integrate new database management systems with the product without changing the product\ufffds software code."
#       ]
#     },
#     {
#       "Requirement": "Maintenance releases should be offered to customers once a year.  The releases should take no longer than 5 minutes for 80% of the customer base to install.",
#       "Actors": [
#         "customers"
#       ],
#       "Actions": [
#         "install"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "Maintenance releases should be offered to customers once a year.  The releases should take no longer than 5 minutes for 80% of the customer base to install."
#       ]
#     },
#     {
#       "Requirement": "The customer should be able to easily integrate new building maps with the product throughout the product\ufffds lifecycle.  Integration of new maps with the product should be possible with little to no support from product support staff.",
#       "Actors": [
#         "product",
#         "product",
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "integrate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The customer should be able to easily integrate new building maps with the product throughout the product\ufffds lifecycle.  Integration of new maps with the product should be possible with little to no support from product support staff."
#       ]
#     },
#     {
#       "Requirement": "The product should be expected to operate within the maximum maintenance budget for a minimum of 2 years.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "maintenance budget"
#       ],
#       "Outcomes": [
#         "The product should be expected to operate within the maximum maintenance budget for a minimum of 2 years."
#       ]
#     },
#     {
#       "Requirement": "Promotional updates to the website should take a day to update.",
#       "Actors": [],
#       "Actions": [
#         "update"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "Promotional updates to the website should take a day to update."
#       ]
#     },
#     {
#       "Requirement": "Washing parameters should be updated during scheduled maintenance hours.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Washing parameters should be updated during scheduled maintenance hours."
#       ]
#     },
#     {
#       "Requirement": "The product should be internet browser independent.The product should run using Internet Explorer and Netscape Navigator.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "run"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should be internet browser independent.The product should run using Internet Explorer and Netscape Navigator."
#       ]
#     },
#     {
#       "Requirement": "The product should continue to operate during upgrade  change or new resource addition.The product should be able to continue to operate with no interruption in service due to new resource additions.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should continue to operate during upgrade  change or new resource addition.The product should be able to continue to operate with no interruption in service due to new resource additions."
#       ]
#     },
#     {
#       "Requirement": "The product should be updated on a regular basis.The product should have a new major feature introduced every six months and quarterly maintenance releases every six months.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should be updated on a regular basis.The product should have a new major feature introduced every six months and quarterly maintenance releases every six months."
#       ]
#     },
#     {
#       "Requirement": "The product should operate with every platform.The product should accommodate any new technology without any change in its architecture.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "accommodate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should operate with every platform.The product should accommodate any new technology without any change in its architecture."
#       ]
#     },
#     {
#       "Requirement": "The WCS system should run queries to the WCS databases once again (on a specified day) to update the available data available to CCR users. Queries should be made to external databases for data refresh once a week.",
#       "Actors": [],
#       "Actions": [
#         "run",
#         "update",
#         "refresh"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The WCS system should run queries to the WCS databases once again (on a specified day) to update the available data available to CCR users. Queries should be made to external databases for data refresh once a week."
#       ]
#     },
#     {
#       "Requirement": "All changes  updates  and additions to the WCS system should be updated in the WCS Developer and WCS User Guides. Every change should be reflected in WCS system documentation",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "All changes  updates  and additions to the WCS system should be updated in the WCS Developer and WCS User Guides. Every change should be reflected in WCS system documentation"
#       ]
#     },
#     {
#       "Requirement": "Application updates should occur between 3AM and 6 AM CST on Wednesday morning during the middle of the NFL season.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Application updates should occur between 3AM and 6 AM CST on Wednesday morning during the middle of the NFL season."
#       ]
#     },
#     {
#       "Requirement": "New System version releases should be released at the beginning of each NFL season.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "New System version releases should be released at the beginning of each NFL season."
#       ]
#     },
#     {
#       "Requirement": "Changes to revenue and expense formulae should be applied to the RFS system  every year  prior to the budgeting process start. Revenue and expense formulae should be updated within one week of their receipt  after which 2 weeks should be allotted to testing of the budget calculations  to be conducted jointly by the project development team and PCG Finance.",
#       "Actors": [
#         "project development team"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Changes to revenue and expense formulae should be applied to the RFS system  every year  prior to the budgeting process start. Revenue and expense formulae should be updated within one week of their receipt  after which 2 weeks should be allotted to testing of the budget calculations  to be conducted jointly by the project development team and PCG Finance."
#       ]
#     },
#     {
#       "Requirement": "New branches/complexes/districts/regions and revenue/expense accounts added to the BDW  should be reflected in the RFS system. 100% of the entities (mentioned above) available as of October month-end  should be loaded into the RFS system  prior to the budget start process.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "New branches/complexes/districts/regions and revenue/expense accounts added to the BDW  should be reflected in the RFS system. 100% of the entities (mentioned above) available as of October month-end  should be loaded into the RFS system  prior to the budget start process."
#       ]
#     }
#   ],
#   "A": [
#     {
#       "Requirement": "The product should be available during normal business hours. As long as the user has access to the client PC  the system should be available 99% of the time during the first six months of operation.",
#       "Actors": [
#         "product",
#         "system"
#       ],
#       "Actions": [
#         "be available",
#         "be available"
#       ],
#       "Conditions": [
#         "normal business hours"
#       ],
#       "Outcomes": [
#         "The product should be available during normal business hours. As long as the user has access to the client PC  the system should be available 99% of the time during the first six months of operation."
#       ]
#     },
#     {
#       "Requirement": "The product should adhere to the corporate online availability schedule.  The application is brought down only within 98% of the scheduled outages per the availability schedule.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "adhere"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should adhere to the corporate online availability schedule.  The application is brought down only within 98% of the scheduled outages per the availability schedule."
#       ]
#     },
#     {
#       "Requirement": "The product should achieve a 98% uptime. The product should not fail more than 2% of the available online time.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "achieve",
#         "fail"
#       ],
#       "Conditions": [
#         "98% uptime"
#       ],
#       "Outcomes": [
#         "The product should achieve a 98% uptime. The product should not fail more than 2% of the available online time."
#       ]
#     },
#     {
#       "Requirement": "Aside from server failure  the software product should achieve 99.99% up time.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "achieve"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "Aside from server failure  the software product should achieve 99.99% up time."
#       ]
#     },
#     {
#       "Requirement": "The website should be available for use 24 hours per day  365 days per year.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [
#         "be available"
#       ],
#       "Conditions": [
#         "24 hours per day",
#         "365 days per year"
#       ],
#       "Outcomes": [
#         "The website should be available for use 24 hours per day  365 days per year."
#       ]
#     },
#     {
#       "Requirement": "The website should achieve 99.5% up time.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [
#         "achieve"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should achieve 99.5% up time."
#       ]
#     },
#     {
#       "Requirement": "All movies should be streamed on demand  at any time of the day.",
#       "Actors": [
#         "movies"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "on demand"
#       ],
#       "Outcomes": [
#         "All movies should be streamed on demand  at any time of the day."
#       ]
#     },
#     {
#       "Requirement": "The system should provide a 24 hour 800 toll free number for support to its customers.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "provide"
#       ],
#       "Conditions": [
#         "24 hour 800 toll free number"
#       ],
#       "Outcomes": [
#         "The system should provide a 24 hour 800 toll free number for support to its customers."
#       ]
#     },
#     {
#       "Requirement": "Velkat staff should be available for phone support between 7am-7pm  M-F to provide technical support to the Izogn administrators.",
#       "Actors": [],
#       "Actions": [
#         "be available",
#         "provide"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "Velkat staff should be available for phone support between 7am-7pm  M-F to provide technical support to the Izogn administrators."
#       ]
#     },
#     {
#       "Requirement": "Defect reports should be available to technical units on a 24x7 basis.",
#       "Actors": [
#         "technical units"
#       ],
#       "Actions": [
#         "be available"
#       ],
#       "Conditions": [
#         "24x7 basis"
#       ],
#       "Outcomes": [
#         "Defect reports should be available to technical units on a 24x7 basis."
#       ]
#     },
#     {
#       "Requirement": "The product should be available 24 hours per day  seven days per week.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be available"
#       ],
#       "Conditions": [
#         "24 hours per day"
#       ],
#       "Outcomes": [
#         "The product should be available 24 hours per day  seven days per week."
#       ]
#     },
#     {
#       "Requirement": "The system should have high availability every day of the year.The system should be available for use between 12:00AM and 6:00PM all days of the year.",
#       "Actors": [
#         "system",
#         "system"
#       ],
#       "Actions": [
#         "have",
#         "be available"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should have high availability every day of the year.The system should be available for use between 12:00AM and 6:00PM all days of the year."
#       ]
#     },
#     {
#       "Requirement": "The system should be available for use between 7:00AM and 11:59PM all days of the year.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "be available"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be available for use between 7:00AM and 11:59PM all days of the year."
#       ]
#     },
#     {
#       "Requirement": "The product should be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product should be available 99.99% of the time for regular business days.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "be available",
#         "be available"
#       ],
#       "Conditions": [
#         "busiest customer service response periods"
#       ],
#       "Outcomes": [
#         "The product should be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product should be available 99.99% of the time for regular business days."
#       ]
#     },
#     {
#       "Requirement": "The WCS system should be available at all times as long as IBM\ufffds internal intranet W3 is accessible. The WCS system should be available 95% of the time IBM\ufffds internal intranet W3 is available.",
#       "Actors": [
#         "system",
#         "system"
#       ],
#       "Actions": [
#         "be available",
#         "be available"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The WCS system should be available at all times as long as IBM\ufffds internal intranet W3 is accessible. The WCS system should be available 95% of the time IBM\ufffds internal intranet W3 is available."
#       ]
#     },
#     {
#       "Requirement": "The application should have a downtime of at most 10 minutes per year.",
#       "Actors": [],
#       "Actions": [
#         "have"
#       ],
#       "Conditions": [
#         "10 minutes per year"
#       ],
#       "Outcomes": [
#         "The application should have a downtime of at most 10 minutes per year."
#       ]
#     },
#     {
#       "Requirement": "The RFS system should be available 24/7  especially during the budgeting period. The RFS system should be available 90% of the time all year  and 98% during the budgeting period. 2% of the time  the system should become available within 1 hour of the time that the situation is reported.",
#       "Actors": [
#         "system",
#         "system",
#         "system"
#       ],
#       "Actions": [
#         "be available",
#         "be available",
#         "become available"
#       ],
#       "Conditions": [
#         "24/7",
#         "budgeting period",
#         "budgeting period",
#         "1 hour"
#       ],
#       "Outcomes": [
#         "The RFS system should be available 24/7  especially during the budgeting period. The RFS system should be available 90% of the time all year  and 98% during the budgeting period. 2% of the time  the system should become available within 1 hour of the time that the situation is reported."
#       ]
#     },
#     {
#       "Requirement": "The product should be available for use 24 hours per day  365 days  per year",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be available"
#       ],
#       "Conditions": [
#         "24 hours per day"
#       ],
#       "Outcomes": [
#         "The product should be available for use 24 hours per day  365 days  per year"
#       ]
#     },
#     {
#       "Requirement": "Out of 1000 accesses to the system  the system is available 999 times.",
#       "Actors": [
#         "system",
#         "system"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "1000 accesses"
#       ],
#       "Outcomes": [
#         "Out of 1000 accesses to the system  the system is available 999 times."
#       ]
#     },
#     {
#       "Requirement": "The system should be available for use between the hours of 8am and 6pm.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "be available"
#       ],
#       "Conditions": [
#         "8am and 6pm"
#       ],
#       "Outcomes": [
#         "The system should be available for use between the hours of 8am and 6pm."
#       ]
#     },
#     {
#       "Requirement": "The system should achieve 95% up time.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "achieve"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should achieve 95% up time."
#       ]
#     }
#   ],
#   "SC": [
#     {
#       "Requirement": "The product should be able to handle up to 1500 simultaneous users. The system should perform with 1500 users as a time.",
#       "Actors": [
#         "product",
#         "system"
#       ],
#       "Actions": [
#         "be able",
#         "handle",
#         "perform"
#       ],
#       "Conditions": [
#         "up to 1500 simultaneous users"
#       ],
#       "Outcomes": [
#         "The product should be able to handle up to 1500 simultaneous users. The system should perform with 1500 users as a time."
#       ]
#     },
#     {
#       "Requirement": "The average number of recycled parts records per day should be 50 000.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The average number of recycled parts records per day should be 50 000."
#       ]
#     },
#     {
#       "Requirement": "The product should be able to handle 10 000 concurrent users within 2 years of the initial launch.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be able",
#         "handle"
#       ],
#       "Conditions": [
#         "within 2 years"
#       ],
#       "Outcomes": [
#         "The product should be able to handle 10 000 concurrent users within 2 years of the initial launch."
#       ]
#     },
#     {
#       "Requirement": "The product should be capable of handling up to 1 000 concurrent requests.  This number should increase to 2 000 by Release 2.  The concurrency capacity should be able to handle peak scheduling times such as early morning and late afternoon hours.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be able",
#         "handle"
#       ],
#       "Conditions": [
#         "up to 1 000 concurrent requests"
#       ],
#       "Outcomes": [
#         "The product should be capable of handling up to 1 000 concurrent requests.  This number should increase to 2 000 by Release 2.  The concurrency capacity should be able to handle peak scheduling times such as early morning and late afternoon hours."
#       ]
#     },
#     {
#       "Requirement": "The product should be able to process 10 000 transactions per hour within two years of its launch.  This number should increase to 20 000 by Release 2.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be able",
#         "process"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should be able to process 10 000 transactions per hour within two years of its launch.  This number should increase to 20 000 by Release 2."
#       ]
#     },
#     {
#       "Requirement": "The product should be expected to operate for at least 5 years for each customer installation.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "operate"
#       ],
#       "Conditions": [
#         "at least 5 years",
#         "for each customer installation"
#       ],
#       "Outcomes": [
#         "The product should be expected to operate for at least 5 years for each customer installation."
#       ]
#     },
#     {
#       "Requirement": "The language of the product should accommodate all of the target market countries. 90% of survey respondents from each target market country should find that the language of the product is acceptable.",
#       "Actors": [
#         "language",
#         "product",
#         "language",
#         "product"
#       ],
#       "Actions": [
#         "accommodate"
#       ],
#       "Conditions": [
#         "90% of survey respondents"
#       ],
#       "Outcomes": [
#         "The language of the product should accommodate all of the target market countries. 90% of survey respondents from each target market country should find that the language of the product is acceptable."
#       ]
#     },
#     {
#       "Requirement": "The streaming server should support 50 simultaneous streaming connections.",
#       "Actors": [
#         "streaming server",
#         "server"
#       ],
#       "Actions": [
#         "support"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The streaming server should support 50 simultaneous streaming connections."
#       ]
#     },
#     {
#       "Requirement": "The streaming server should support a maximum of 700 movies; new servers can be added to support more movies.",
#       "Actors": [
#         "streaming server",
#         "server"
#       ],
#       "Actions": [
#         "support",
#         "support"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The streaming server should support a maximum of 700 movies; new servers can be added to support more movies."
#       ]
#     },
#     {
#       "Requirement": "The server should support a maximum of 1 000 simultaneous users.",
#       "Actors": [
#         "server"
#       ],
#       "Actions": [
#         "support"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The server should support a maximum of 1 000 simultaneous users."
#       ]
#     },
#     {
#       "Requirement": "The website should be capable of supporting 100 000 customers.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should be capable of supporting 100 000 customers."
#       ]
#     },
#     {
#       "Requirement": "The product should be able to process all transactions.The product should process minimum of 1 million transactions per year.",
#       "Actors": [
#         "product",
#         "product"
#       ],
#       "Actions": [
#         "be able",
#         "process",
#         "process"
#       ],
#       "Conditions": [
#         "minimum of 1 million transactions per year"
#       ],
#       "Outcomes": [
#         "The product should be able to process all transactions.The product should process minimum of 1 million transactions per year."
#       ]
#     },
#     {
#       "Requirement": "The WCS system should have the ability to connect other designated WCS databases currently not included in the system.",
#       "Actors": [
#         "system",
#         "system"
#       ],
#       "Actions": [
#         "connect"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The WCS system should have the ability to connect other designated WCS databases currently not included in the system."
#       ]
#     },
#     {
#       "Requirement": "The WCS system should have the ability to include data for regions outside the United States and be accessed by users outside of the United States if approved by CCR management.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "include"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The WCS system should have the ability to include data for regions outside the United States and be accessed by users outside of the United States if approved by CCR management."
#       ]
#     },
#     {
#       "Requirement": "The product should be able to support multiple remote users",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be able",
#         "support"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should be able to support multiple remote users"
#       ]
#     },
#     {
#       "Requirement": "The product should be able support 1000 simultaneous users.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "be able",
#         "support"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should be able support 1000 simultaneous users."
#       ]
#     },
#     {
#       "Requirement": "The product should be capable of handling the existing 1000 users. This number is expected to grow 5 times within the next year.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should be capable of handling the existing 1000 users. This number is expected to grow 5 times within the next year."
#       ]
#     },
#     {
#       "Requirement": "system should be able to handle all of the user requests/usage during business hours.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "be able",
#         "handle"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "system should be able to handle all of the user requests/usage during business hours."
#       ]
#     },
#     {
#       "Requirement": "The system should cater to 10 simultaneous users from 9am to 5pm.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should cater to 10 simultaneous users from 9am to 5pm."
#       ]
#     },
#     {
#       "Requirement": "The system should be capable of processing 100% of nursing students and their classes for the next 10 years.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [],
#       "Conditions": [
#         "the next 10 years"
#       ],
#       "Outcomes": [
#         "The system should be capable of processing 100% of nursing students and their classes for the next 10 years."
#       ]
#     },
#     {
#       "Requirement": "The system should be expected to manage the nursing program curriculum and class/clinical scheduling for a minimum of 5 years.",
#       "Actors": [
#         "system"
#       ],
#       "Actions": [
#         "manage"
#       ],
#       "Conditions": [
#         "a minimum of 5 years"
#       ],
#       "Outcomes": [
#         "The system should be expected to manage the nursing program curriculum and class/clinical scheduling for a minimum of 5 years."
#       ]
#     }
#   ],
#   "LF": [
#     {
#       "Requirement": "The application should match the color of the schema set forth by Department of Homeland Security",
#       "Actors": [
#         "application"
#       ],
#       "Actions": [
#         "match"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The application should match the color of the schema set forth by Department of Homeland Security"
#       ]
#     },
#     {
#       "Requirement": "The product should comply with corporate User Interface Guidelines",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should comply with corporate User Interface Guidelines"
#       ]
#     },
#     {
#       "Requirement": "The product should comply with corporate color scheme",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "comply"
#       ],
#       "Conditions": [
#         "corporate color scheme"
#       ],
#       "Outcomes": [
#         "The product should comply with corporate color scheme"
#       ]
#     },
#     {
#       "Requirement": "The appearance of the product should appear professional",
#       "Actors": [
#         "appearance",
#         "product"
#       ],
#       "Actions": [
#         "appear"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The appearance of the product should appear professional"
#       ]
#     },
#     {
#       "Requirement": "The product\ufffds Look and Feel should be able to incorporate aspects of the customer\ufffds organization such as logo  branding  and identity",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "incorporate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product\ufffds Look and Feel should be able to incorporate aspects of the customer\ufffds organization such as logo  branding  and identity"
#       ]
#     },
#     {
#       "Requirement": "The product should have a conservative and professional appearance.",
#       "Actors": [
#         "product",
#         "appearance"
#       ],
#       "Actions": [
#         "have"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should have a conservative and professional appearance."
#       ]
#     },
#     {
#       "Requirement": "The website should be attractive to all audiences.  The website should appear to be fun and the colors should be bright and vibrant.",
#       "Actors": [
#         "website",
#         "website"
#       ],
#       "Actions": [
#         "appear"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should be attractive to all audiences.  The website should appear to be fun and the colors should be bright and vibrant."
#       ]
#     },
#     {
#       "Requirement": "The website should have an African feel  but should not alienate non-Africans.  The website should use animation on pages which are describing the services  to grab the users attention and encourage them to sign up.",
#       "Actors": [
#         "website",
#         "website"
#       ],
#       "Actions": [
#         "have",
#         "use"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should have an African feel  but should not alienate non-Africans.  The website should use animation on pages which are describing the services  to grab the users attention and encourage them to sign up."
#       ]
#     },
#     {
#       "Requirement": "The website design should be modern  clean  and concise.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The website design should be modern  clean  and concise."
#       ]
#     },
#     {
#       "Requirement": "The website should cater to all tribes in Nigeria.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should cater to all tribes in Nigeria."
#       ]
#     },
#     {
#       "Requirement": "The website should not be offensive to religious or ethnic groups.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should not be offensive to religious or ethnic groups."
#       ]
#     },
#     {
#       "Requirement": "The website should appeal to all Africans  not only Nigerians.",
#       "Actors": [
#         "website"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The website should appeal to all Africans  not only Nigerians."
#       ]
#     },
#     {
#       "Requirement": "The product should simulate the look of ships at sea.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "simulate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should simulate the look of ships at sea."
#       ]
#     },
#     {
#       "Requirement": "The product should display the grids within a circle as a view from a periscope.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "display"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should display the grids within a circle as a view from a periscope."
#       ]
#     },
#     {
#       "Requirement": "The product should display each type of ship in a grid using an image of the specific type of ship.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "display"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should display each type of ship in a grid using an image of the specific type of ship."
#       ]
#     },
#     {
#       "Requirement": "When the offensive player takes a shot  the product should simulate the sound of a ship at sea.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "simulate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "When the offensive player takes a shot  the product should simulate the sound of a ship at sea."
#       ]
#     },
#     {
#       "Requirement": "When a shot is marked as a miss  the product should simulate the sound of a shot missing its target.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "simulate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "When a shot is marked as a miss  the product should simulate the sound of a shot missing its target."
#       ]
#     },
#     {
#       "Requirement": "When a shot is marked as a hit  the product should simulate the sound of a shot hitting its target.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "simulate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "When a shot is marked as a hit  the product should simulate the sound of a shot hitting its target."
#       ]
#     },
#     {
#       "Requirement": "When a ship is sunk  the product should simulate the sound of a sinking ship.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "simulate"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "When a ship is sunk  the product should simulate the sound of a sinking ship."
#       ]
#     },
#     {
#       "Requirement": "The interface should have a simple look. In the interface and usability survey  90% of beta testers should report that the interface is adequately simple.",
#       "Actors": [
#         "interface",
#         "interface",
#         "interface"
#       ],
#       "Actions": [
#         "have"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The interface should have a simple look. In the interface and usability survey  90% of beta testers should report that the interface is adequately simple."
#       ]
#     },
#     {
#       "Requirement": "The interface should be appealing to callers and supervisors. In the interface and usability survey  80% of beta testers should report that the interface is appealing.",
#       "Actors": [
#         "interface",
#         "interface",
#         "interface"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The interface should be appealing to callers and supervisors. In the interface and usability survey  80% of beta testers should report that the interface is appealing."
#       ]
#     },
#     {
#       "Requirement": "The product should provide GUI based Monitoring Services.System Administrators should monitor message exchanges should predict and determine problems and should also provide internal and external support.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "provide",
#         "provide"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should provide GUI based Monitoring Services.System Administrators should monitor message exchanges should predict and determine problems and should also provide internal and external support."
#       ]
#     },
#     {
#       "Requirement": "The product should comply with City of Chicago Application Development Guide Framework.Application Development Framework should provide structured Graphical User Interface.",
#       "Actors": [
#         "product"
#       ],
#       "Actions": [
#         "comply",
#         "provide"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The product should comply with City of Chicago Application Development Guide Framework.Application Development Framework should provide structured Graphical User Interface."
#       ]
#     },
#     {
#       "Requirement": "The system should use IBM and CCR branding standards. The interface should have one IBM logo and one CCR logo.",
#       "Actors": [
#         "system",
#         "interface"
#       ],
#       "Actions": [
#         "use",
#         "have"
#       ],
# ...
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators and Nursing Staff Members should have the ability to specify which classes are required for a Program of Study"
#       ]
#     },
#     {
#       "Requirement": "The system should be able to display a report of needed classes for a given quarter for all cohorts of all programs for Program Administrators/Nursing Staff Members\ufffd planning purposes.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be able to display a report of needed classes for a given quarter for all cohorts of all programs for Program Administrators/Nursing Staff Members\ufffd planning purposes."
#       ]
#     },
#     {
#       "Requirement": "The report of needed classes should include (but not be limited to) classes to be offered  number of sections needed  number of labs needed  and room types needed.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The report of needed classes should include (but not be limited to) classes to be offered  number of sections needed  number of labs needed  and room types needed."
#       ]
#     },
#     {
#       "Requirement": "Classes for a given cohort should not conflict with regards to the time and day that they are offered.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Classes for a given cohort should not conflict with regards to the time and day that they are offered."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators and Nursing Staff Members should be able to add a new clinical site into the system.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators and Nursing Staff Members should be able to add a new clinical site into the system."
#       ]
#     },
#     {
#       "Requirement": "Clinical site information should include (but not be limited to) the name of the site  contact person  and contact information.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Clinical site information should include (but not be limited to) the name of the site  contact person  and contact information."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators and Nursing Staff Members should be able to add a new clinical lab section for an existing clinical class into the System.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators and Nursing Staff Members should be able to add a new clinical lab section for an existing clinical class into the System."
#       ]
#     },
#     {
#       "Requirement": "A clinical lab section should include the clinical site name  the class  instructor  day and time of the lab.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "A clinical lab section should include the clinical site name  the class  instructor  day and time of the lab."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators and Nursing Staff Members should be able to add a student who has registered for a clinical class to a clinical lab section for that class.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators and Nursing Staff Members should be able to add a student who has registered for a clinical class to a clinical lab section for that class."
#       ]
#     },
#     {
#       "Requirement": "The system should allow a Program Administrator or Nursing staff member to remove a student from a clinical lab section.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should allow a Program Administrator or Nursing staff member to remove a student from a clinical lab section."
#       ]
#     },
#     {
#       "Requirement": "The system should allow a Program Administrator/Nursing Staff Member to move a student from one clinical lab section to another clinical lab section corresponding to the same clinical class.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should allow a Program Administrator/Nursing Staff Member to move a student from one clinical lab section to another clinical lab section corresponding to the same clinical class."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators/Nursing Staff Members should be able to cancel a clinical lab section only if there are no students registered for that clinical lab section.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators/Nursing Staff Members should be able to cancel a clinical lab section only if there are no students registered for that clinical lab section."
#       ]
#     },
#     {
#       "Requirement": "A Program Administrator/Nursing Staff Member should be able to add a new nursing student to the system.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "A Program Administrator/Nursing Staff Member should be able to add a new nursing student to the system."
#       ]
#     },
#     {
#       "Requirement": "A staff member should have the ability to manage the progress of a part time student  which includes modifying their sequence of classes and timeline of classes.",
#       "Actors": [],
#       "Actions": [
#         "manage"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "A staff member should have the ability to manage the progress of a part time student  which includes modifying their sequence of classes and timeline of classes."
#       ]
#     },
#     {
#       "Requirement": "The system should be able to display a printable summary for individual cohorts  which should include the students enlisted  the Program of study  sequence of classes  cohort progress through the program  and timeline of completion.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be able to display a printable summary for individual cohorts  which should include the students enlisted  the Program of study  sequence of classes  cohort progress through the program  and timeline of completion."
#       ]
#     },
#     {
#       "Requirement": "The system should be able to display a printable summary for individual clinical sites  which should include information on labs being held at that site for the given quarter (Clinical site  general information on labs held at that location  dates and times of all labs held there).",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be able to display a printable summary for individual clinical sites  which should include information on labs being held at that site for the given quarter (Clinical site  general information on labs held at that location  dates and times of all labs held there)."
#       ]
#     },
#     {
#       "Requirement": "The system should be able to display a printable summary for individual clinical labs  which should include (but not be limited to) class name  class number  lab section  listing of students enrolled  instructor  day(s)  time  and location.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be able to display a printable summary for individual clinical labs  which should include (but not be limited to) class name  class number  lab section  listing of students enrolled  instructor  day(s)  time  and location."
#       ]
#     },
#     {
#       "Requirement": "The system should be able to display a printable summary for individual nursing students  which should include (but not be limited to) student name  student ID  admission date  classes  credits  GPA  and the cohort that the student is enrolled in.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be able to display a printable summary for individual nursing students  which should include (but not be limited to) student name  student ID  admission date  classes  credits  GPA  and the cohort that the student is enrolled in."
#       ]
#     },
#     {
#       "Requirement": "The system should be able to display a printable summary of the system log.",
#       "Actors": [],
#       "Actions": [
#         "log"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should be able to display a printable summary of the system log."
#       ]
#     },
#     {
#       "Requirement": "The system should contain contact information (e-mail and phone number) for all people relevant to the system  including (but not limited to) staff members  students  lecture instructors  clinical lab instructors  and clinical site administrators.",
#       "Actors": [
#         "staff members"
#       ],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should contain contact information (e-mail and phone number) for all people relevant to the system  including (but not limited to) staff members  students  lecture instructors  clinical lab instructors  and clinical site administrators."
#       ]
#     },
#     {
#       "Requirement": "The system should use the stored e-mail addresses as a primary means of communicating information to affected parties.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should use the stored e-mail addresses as a primary means of communicating information to affected parties."
#       ]
#     },
#     {
#       "Requirement": "The system should notify affected parties for routine communication purposes  including but not limited to informing students of upcoming offered classes (timeline) and what their schedule should be/should be.",
#       "Actors": [],
#       "Actions": [
#         "notify",
#         "schedule"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should notify affected parties for routine communication purposes  including but not limited to informing students of upcoming offered classes (timeline) and what their schedule should be/should be."
#       ]
#     },
#     {
#       "Requirement": "The system should notify affected parties when changes occur affecting clinicals  including but not limited to clinical section capacity changes  and clinical section cancellations.",
#       "Actors": [],
#       "Actions": [
#         "notify"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should notify affected parties when changes occur affecting clinicals  including but not limited to clinical section capacity changes  and clinical section cancellations."
#       ]
#     },
#     {
#       "Requirement": "The system should notify affected parties when changes occur affecting classes  including but not limited to class cancellations  class section detail changes  and changes to class offerings for a given quarter.",
#       "Actors": [],
#       "Actions": [
#         "notify"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should notify affected parties when changes occur affecting classes  including but not limited to class cancellations  class section detail changes  and changes to class offerings for a given quarter."
#       ]
#     },
#     {
#       "Requirement": "The system should notify affected parties when changes occur affecting cohorts  including but not limited to changes to the sequence for a cohort\ufffds program of study and changes to a given week\ufffds schedule (lab cancelled this week due to instructor illness).",
#       "Actors": [],
#       "Actions": [
#         "notify",
#         "schedule"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should notify affected parties when changes occur affecting cohorts  including but not limited to changes to the sequence for a cohort\ufffds program of study and changes to a given week\ufffds schedule (lab cancelled this week due to instructor illness)."
#       ]
#     },
#     {
#       "Requirement": "The system should notify affected parties when changes occur affecting specific students  including but not limited to changing a student\ufffds status from full time to part time and moving a student to a different clinical section.",
#       "Actors": [],
#       "Actions": [
#         "notify"
#       ],
#       "Conditions": [],
#       "Outcomes": [
#         "The system should notify affected parties when changes occur affecting specific students  including but not limited to changing a student\ufffds status from full time to part time and moving a student to a different clinical section."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators/Nursing Staff Members should have the ability to modify information relating to cohorts  including cohort identifier  program of study  preferred sequence of classes and quarters that a cohort should be taking specific classes.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators/Nursing Staff Members should have the ability to modify information relating to cohorts  including cohort identifier  program of study  preferred sequence of classes and quarters that a cohort should be taking specific classes."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Program of Study within the Nursing Department  including the Program of study name  and required classes for that Program of Study.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Program of Study within the Nursing Department  including the Program of study name  and required classes for that Program of Study."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Clinical Site  including the clinical site name  site contact person  contact information  and address.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Clinical Site  including the clinical site name  site contact person  contact information  and address."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Clinical Lab Section  including the clinical site name  the department/section for the lab  the class  instructor  day and time of lab  and contact information.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Clinical Lab Section  including the clinical site name  the department/section for the lab  the class  instructor  day and time of lab  and contact information."
#       ]
#     },
#     {
#       "Requirement": "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Nursing Student  including student ID  student name  phone number  e-mail  status (full time or part time)  and program of study.",
#       "Actors": [],
#       "Actions": [],
#       "Conditions": [],
#       "Outcomes": [
#         "Program Administrators/Nursing Staff Members should have the ability to modify information relating to a Nursing Student  including student ID  student name  phone number  e-mail  status (full time or part time)  and program of study."
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### **4.Rule based approach for Test case generation**

# %%
import json

def parse_requirements(requirements_data):
    if isinstance(requirements_data, str):
        try:
            return json.loads(requirements_data)
        except json.JSONDecodeError:
            print(f"Error decoding JSON: {requirements_data}")
            return {}
    return requirements_data

def rule_based_test_case_generator(parsed_requirements):
    test_cases = []

    for category, requirements in parsed_requirements.items():
        for req in requirements:
            requirement = parse_requirements(req)

            if isinstance(requirement, dict):
                actions = requirement.get('Actions', [])
                actors = requirement.get('Actors', [])
                conditions = requirement.get('Conditions', ['No specific conditions identified'])
                outcomes = requirement.get('Outcomes', [])

                # Generate multiple test cases by combining actions, actors, and conditions
                for action in actions:
                    for actor in actors:
                        for condition in conditions:
                            for outcome in outcomes:
                                test_case = {
                                    'Test Case Title': generate_test_case_title(requirement, action, condition),
                                    'Test Steps': generate_test_steps(requirement, action, condition),
                                    'Preconditions': generate_preconditions(requirement, condition),
                                    'Expected Result': generate_expected_result(requirement)
                                }
                                test_cases.append(test_case)
            else:
                print(f"Skipping invalid requirement format: {requirement}")

    return test_cases

def generate_test_case_title(requirement, action, condition):
    actor = requirement.get('Actors', [''])[0]
    title = f"Verify {action} by {actor}"
    if condition and condition != 'No specific conditions identified':
        title += f" with {condition}"
    return title

def generate_test_steps(requirement, action, condition):
    steps = []
    steps.append(f"Step 1: Ensure the following conditions are met: {condition}.")
    steps.append(f"Step 2: Perform the action '{action}'.")
    steps.append(f"Step 3: Verify the outcome matches the expected result: '{requirement.get('Outcomes', [''])[0]}'")
    return '\n'.join(steps)

def generate_preconditions(requirement, condition):
    return condition

def generate_expected_result(requirement):
    return requirement.get('Outcomes', ['No expected result provided'])[0]


with open('/content/parsed_requirements.json') as f:
    parsed_requirements = json.load(f)

# Generate test cases using rule-based approach
test_cases = rule_based_test_case_generator(parsed_requirements)

# Function to print the first 100 test cases and total number of test cases
def print_first_100_test_cases(test_cases):
    total_cases = len(test_cases)
    print(f"Total number of test cases: {total_cases}\n")

    for i, case in enumerate(test_cases[:100], 1):  # Print only the first 100 test cases
        print(f"Test Case {i}")
        print("-" * 80)
        print(f"Title: {case['Test Case Title']}")
        print("Steps:")
        print(f"{case['Test Steps']}")
        print(f"Preconditions: {case['Preconditions']}")
        print(f"Expected Result: {case['Expected Result']}")
        print("\n" + "=" * 80 + "\n")

    if total_cases > 100:
        print(f"Note: Only the first 100 of {total_cases} test cases are displayed.")

print_first_100_test_cases(test_cases)
# Out:
# Total number of test cases: 12740
#
# Test Case 1
# --------------------------------------------------------------------------------
# Title: Verify run by product with Windows CE
# Steps:
# Step 1: Ensure the following conditions are met: Windows CE.
# Step 2: Perform the action 'run'.
# Step 3: Verify the outcome matches the expected result: 'The product is expected to run on Windows CE and Palm operating systems.'
# Preconditions: Windows CE
# Expected Result: The product is expected to run on Windows CE and Palm operating systems.
#
# ================================================================================
#
# Test Case 2
# --------------------------------------------------------------------------------
# Title: Verify run by product with on
# Steps:
# Step 1: Ensure the following conditions are met: on.
# Step 2: Perform the action 'run'.
# Step 3: Verify the outcome matches the expected result: 'The product is expected to run on Windows CE and Palm operating systems.'
# Preconditions: on
# Expected Result: The product is expected to run on Windows CE and Palm operating systems.
#
# ================================================================================
#
# Test Case 3
# --------------------------------------------------------------------------------
# Title: Verify expect by product with Windows CE
# Steps:
# Step 1: Ensure the following conditions are met: Windows CE.
# Step 2: Perform the action 'expect'.
# Step 3: Verify the outcome matches the expected result: 'The product is expected to run on Windows CE and Palm operating systems.'
# Preconditions: Windows CE
# Expected Result: The product is expected to run on Windows CE and Palm operating systems.
#
# ================================================================================
#
# Test Case 4
# --------------------------------------------------------------------------------
# Title: Verify expect by product with on
# Steps:
# Step 1: Ensure the following conditions are met: on.
# Step 2: Perform the action 'expect'.
# Step 3: Verify the outcome matches the expected result: 'The product is expected to run on Windows CE and Palm operating systems.'
# Preconditions: on
# Expected Result: The product is expected to run on Windows CE and Palm operating systems.
#
# ================================================================================
#
# Test Case 5
# --------------------------------------------------------------------------------
# Title: Verify create by product with exception log
# Steps:
# Step 1: Ensure the following conditions are met: exception log.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: exception log
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 6
# --------------------------------------------------------------------------------
# Title: Verify create by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: of
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 7
# --------------------------------------------------------------------------------
# Title: Verify create by product with within
# Steps:
# Step 1: Ensure the following conditions are met: within.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: within
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 8
# --------------------------------------------------------------------------------
# Title: Verify create by product with for
# Steps:
# Step 1: Ensure the following conditions are met: for.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: for
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 9
# --------------------------------------------------------------------------------
# Title: Verify create by product with to
# Steps:
# Step 1: Ensure the following conditions are met: to.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: to
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 10
# --------------------------------------------------------------------------------
# Title: Verify create by product with exception log
# Steps:
# Step 1: Ensure the following conditions are met: exception log.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: exception log
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 11
# --------------------------------------------------------------------------------
# Title: Verify create by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: of
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 12
# --------------------------------------------------------------------------------
# Title: Verify create by product with within
# Steps:
# Step 1: Ensure the following conditions are met: within.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: within
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 13
# --------------------------------------------------------------------------------
# Title: Verify create by product with for
# Steps:
# Step 1: Ensure the following conditions are met: for.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: for
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 14
# --------------------------------------------------------------------------------
# Title: Verify create by product with to
# Steps:
# Step 1: Ensure the following conditions are met: to.
# Step 2: Perform the action 'create'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: to
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 15
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with exception log
# Steps:
# Step 1: Ensure the following conditions are met: exception log.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: exception log
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 16
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: of
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 17
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with within
# Steps:
# Step 1: Ensure the following conditions are met: within.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: within
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 18
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with for
# Steps:
# Step 1: Ensure the following conditions are met: for.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: for
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 19
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with to
# Steps:
# Step 1: Ensure the following conditions are met: to.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: to
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 20
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with exception log
# Steps:
# Step 1: Ensure the following conditions are met: exception log.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: exception log
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 21
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: of
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 22
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with within
# Steps:
# Step 1: Ensure the following conditions are met: within.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: within
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 23
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with for
# Steps:
# Step 1: Ensure the following conditions are met: for.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: for
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 24
# --------------------------------------------------------------------------------
# Title: Verify encounter by product with to
# Steps:
# Step 1: Ensure the following conditions are met: to.
# Step 2: Perform the action 'encounter'.
# Step 3: Verify the outcome matches the expected result: 'The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.'
# Preconditions: to
# Expected Result: The product should create an exception log of problems encountered within the product for transmission to our company for analysis and resolution.
#
# ================================================================================
#
# Test Case 25
# --------------------------------------------------------------------------------
# Title: Verify remain by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 26
# --------------------------------------------------------------------------------
# Title: Verify remain by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 27
# --------------------------------------------------------------------------------
# Title: Verify remain by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 28
# --------------------------------------------------------------------------------
# Title: Verify remain by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 29
# --------------------------------------------------------------------------------
# Title: Verify remain by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 30
# --------------------------------------------------------------------------------
# Title: Verify remain by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 31
# --------------------------------------------------------------------------------
# Title: Verify remain by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 32
# --------------------------------------------------------------------------------
# Title: Verify remain by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 33
# --------------------------------------------------------------------------------
# Title: Verify remain by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 34
# --------------------------------------------------------------------------------
# Title: Verify remain by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 35
# --------------------------------------------------------------------------------
# Title: Verify remain by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 36
# --------------------------------------------------------------------------------
# Title: Verify remain by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 37
# --------------------------------------------------------------------------------
# Title: Verify remain by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 38
# --------------------------------------------------------------------------------
# Title: Verify remain by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 39
# --------------------------------------------------------------------------------
# Title: Verify remain by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 40
# --------------------------------------------------------------------------------
# Title: Verify remain by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 41
# --------------------------------------------------------------------------------
# Title: Verify remain by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 42
# --------------------------------------------------------------------------------
# Title: Verify remain by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 43
# --------------------------------------------------------------------------------
# Title: Verify remain by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 44
# --------------------------------------------------------------------------------
# Title: Verify remain by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'remain'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 45
# --------------------------------------------------------------------------------
# Title: Verify crash by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 46
# --------------------------------------------------------------------------------
# Title: Verify crash by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 47
# --------------------------------------------------------------------------------
# Title: Verify crash by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 48
# --------------------------------------------------------------------------------
# Title: Verify crash by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 49
# --------------------------------------------------------------------------------
# Title: Verify crash by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 50
# --------------------------------------------------------------------------------
# Title: Verify crash by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 51
# --------------------------------------------------------------------------------
# Title: Verify crash by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 52
# --------------------------------------------------------------------------------
# Title: Verify crash by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 53
# --------------------------------------------------------------------------------
# Title: Verify crash by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 54
# --------------------------------------------------------------------------------
# Title: Verify crash by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 55
# --------------------------------------------------------------------------------
# Title: Verify crash by product with of
# Steps:
# Step 1: Ensure the following conditions are met: of.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: of
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 56
# --------------------------------------------------------------------------------
# Title: Verify crash by product with into
# Steps:
# Step 1: Ensure the following conditions are met: into.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: into
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 57
# --------------------------------------------------------------------------------
# Title: Verify crash by product with malicious data
# Steps:
# Step 1: Ensure the following conditions are met: malicious data.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: malicious data
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# Test Case 58
# --------------------------------------------------------------------------------
# Title: Verify crash by product with as
# Steps:
# Step 1: Ensure the following conditions are met: as.
# Step 2: Perform the action 'crash'.
# Step 3: Verify the outcome matches the expected result: 'The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.'
# Preconditions: as
# Expected Result: The product and/or dependent databases/filesystems should remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems should not crash 100% of the time that malicious data is input into the product.
#
# ================================================================================
#
# ...
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: based
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 79
# --------------------------------------------------------------------------------
# Title: Verify have by product with on
# Steps:
# Step 1: Ensure the following conditions are met: on.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: on
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 80
# --------------------------------------------------------------------------------
# Title: Verify have by product with standards adoption
# Steps:
# Step 1: Ensure the following conditions are met: standards adoption.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: standards adoption
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 81
# --------------------------------------------------------------------------------
# Title: Verify have by product with based
# Steps:
# Step 1: Ensure the following conditions are met: based.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: based
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 82
# --------------------------------------------------------------------------------
# Title: Verify have by product with on
# Steps:
# Step 1: Ensure the following conditions are met: on.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: on
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 83
# --------------------------------------------------------------------------------
# Title: Verify base by product with standards adoption
# Steps:
# Step 1: Ensure the following conditions are met: standards adoption.
# Step 2: Perform the action 'base'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: standards adoption
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 84
# --------------------------------------------------------------------------------
# Title: Verify base by product with based
# Steps:
# Step 1: Ensure the following conditions are met: based.
# Step 2: Perform the action 'base'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: based
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 85
# --------------------------------------------------------------------------------
# Title: Verify base by product with on
# Steps:
# Step 1: Ensure the following conditions are met: on.
# Step 2: Perform the action 'base'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: on
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 86
# --------------------------------------------------------------------------------
# Title: Verify base by product with standards adoption
# Steps:
# Step 1: Ensure the following conditions are met: standards adoption.
# Step 2: Perform the action 'base'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: standards adoption
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 87
# --------------------------------------------------------------------------------
# Title: Verify base by product with based
# Steps:
# Step 1: Ensure the following conditions are met: based.
# Step 2: Perform the action 'base'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: based
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 88
# --------------------------------------------------------------------------------
# Title: Verify base by product with on
# Steps:
# Step 1: Ensure the following conditions are met: on.
# Step 2: Perform the action 'base'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust.The product should have fault avoidance based on standards adoption.'
# Preconditions: on
# Expected Result: The product should be robust.The product should have fault avoidance based on standards adoption.
#
# ================================================================================
#
# Test Case 89
# --------------------------------------------------------------------------------
# Title: Verify have by product with fault tolerance
# Steps:
# Step 1: Ensure the following conditions are met: fault tolerance.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: fault tolerance
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 90
# --------------------------------------------------------------------------------
# Title: Verify have by product with fault tolerance
# Steps:
# Step 1: Ensure the following conditions are met: fault tolerance.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: fault tolerance
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 91
# --------------------------------------------------------------------------------
# Title: Verify have by product with recovery technique
# Steps:
# Step 1: Ensure the following conditions are met: recovery technique.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: recovery technique
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 92
# --------------------------------------------------------------------------------
# Title: Verify have by product with compensatory transaction
# Steps:
# Step 1: Ensure the following conditions are met: compensatory transaction.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: compensatory transaction
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 93
# --------------------------------------------------------------------------------
# Title: Verify have by product with with
# Steps:
# Step 1: Ensure the following conditions are met: with.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: with
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 94
# --------------------------------------------------------------------------------
# Title: Verify have by product with by
# Steps:
# Step 1: Ensure the following conditions are met: by.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: by
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 95
# --------------------------------------------------------------------------------
# Title: Verify have by product with around
# Steps:
# Step 1: Ensure the following conditions are met: around.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: around
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 96
# --------------------------------------------------------------------------------
# Title: Verify have by product with fault tolerance
# Steps:
# Step 1: Ensure the following conditions are met: fault tolerance.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: fault tolerance
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 97
# --------------------------------------------------------------------------------
# Title: Verify have by product with fault tolerance
# Steps:
# Step 1: Ensure the following conditions are met: fault tolerance.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: fault tolerance
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 98
# --------------------------------------------------------------------------------
# Title: Verify have by product with recovery technique
# Steps:
# Step 1: Ensure the following conditions are met: recovery technique.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: recovery technique
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 99
# --------------------------------------------------------------------------------
# Title: Verify have by product with compensatory transaction
# Steps:
# Step 1: Ensure the following conditions are met: compensatory transaction.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: compensatory transaction
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Test Case 100
# --------------------------------------------------------------------------------
# Title: Verify have by product with with
# Steps:
# Step 1: Ensure the following conditions are met: with.
# Step 2: Perform the action 'have'.
# Step 3: Verify the outcome matches the expected result: 'The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.'
# Preconditions: with
# Expected Result: The product should be robust with fault tolerance.The product should have fault tolerance by using recovery technique compensatory transaction and routing around failures.
#
# ================================================================================
#
# Note: Only the first 100 of 12740 test cases are displayed.
